# %%
import dagstermill

# %%
raise Exception("Someone set up us the bomb")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-f0bc72d781b2> in <module>
# ----> 1 raise Exception('Someone set up us the bomb')
#
# Exception: Someone set up us the bomb
