# %% [markdown]
# # Assets
#
# An asset is an object in persistent storage, such as a table, file, or persisted machine learning model. An asset definition is a description, in code, of an asset that should exist and how to produce and update that asset.

# %%
from functools import partial
from nbdoc.showdoc import ShowDoc

from dagster import asset

# %%
ShowDoc(asset)
# Out:
# <HTMLRemove>
# <h3> <code>function</code> <span style="color:Brown">asset</span> <em>(compute_fn: Optional[Callable[..., Any]] = None, *, name: Optional[str] = None, key_prefix: Union[str, Sequence[str], NoneType] = None, ins: Optional[Mapping[str, dagster._core.definitions.asset_in.AssetIn]] = None, deps: Optional[Iterable[Union[dagster._core.definitions.asset_key.AssetKey, str, Sequence[str], dagster._core.definitions.asset_spec.AssetSpec, ForwardRef('AssetsDefinition'), dagster._core.definitions.source_asset.SourceAsset, ForwardRef('AssetDep')]]] = None, metadata: Optional[Mapping[str, Any]] = None, tags: Optional[Mapping[str, str]] = None, description: Optional[str] = None, config_schema: Union[Type[Union[bool, float, int, str]], Type[Union[Dict[Any, Any], List[Any]]], ForwardRef('ConfigType'), ForwardRef('Field'), Mapping[str, Any], Sequence[Any], NoneType] = None, required_resource_keys: Optional[AbstractSet[str]] = None, resource_defs: Optional[Mapping[str, object]] = None, io_manager_def: Optional[object] = None, io_manager_key: Optional[str] = None, compute_kind: Optional[str] = None, dagster_type: Optional[dagster._core.types.dagster_type.DagsterType] = None, partitions_def: Optional[dagster._core.definitions.partition.PartitionsDefinition] = None, op_tags: Optional[Mapping[str, Any]] = None, group_name: Optional[str] = None, output_required: bool = True, freshness_policy: Optional[dagster._core.definitions.freshness_policy.FreshnessPolicy] = None, automation_condition: Optional[dagster._core.definitions.declarative_automation.automation_condition.AutomationCondition] = None, backfill_policy: Optional[dagster._core.definitions.backfill_policy.BackfillPolicy] = None, retry_policy: Optional[dagster._core.definitions.policy.RetryPolicy] = None, code_version: Optional[str] = None, key: Union[dagster._core.definitions.asset_key.AssetKey, str, Sequence[str], NoneType] = None, non_argument_deps: Union[Set[dagster._core.definitions.asset_key.AssetKey], Set[str], NoneType] = None, check_specs: Optional[Sequence[dagster._core.definitions.asset_check_spec.AssetCheckSpec]] = None, owners: Optional[Sequence[str]] = None, auto_materialize_policy: Optional[dagster._core.definitions.auto_materialize_policy.AutoMaterializePolicy] = None) -> Union[dagster._core.definitions.assets.AssetsDefinition, Callable[[Callable[..., Any]], dagster._core.definitions.assets.AssetsDefinition]]</em></h3><p><blockquote>Create&nbsp;a&nbsp;definition&nbsp;for&nbsp;how&nbsp;to&nbsp;compute&nbsp;an&nbsp;asset.<br><br>A&nbsp;software-defined&nbsp;asset&nbsp;is&nbsp;the&nbsp;combination&nbsp;of:<br>&nbsp;&nbsp;1.&nbsp;An&nbsp;asset&nbsp;key,&nbsp;e.g.&nbsp;the&nbsp;name&nbsp;of&nbsp;a&nbsp;table.<br>&nbsp;&nbsp;2.&nbsp;A&nbsp;function,&nbsp;which&nbsp;can&nbsp;be&nbsp;run&nbsp;to&nbsp;compute&nbsp;the&nbsp;contents&nbsp;of&nbsp;the&nbsp;asset.<br>&nbsp;&nbsp;3.&nbsp;A&nbsp;set&nbsp;of&nbsp;upstream&nbsp;assets&nbsp;that&nbsp;are&nbsp;provided&nbsp;as&nbsp;inputs&nbsp;to&nbsp;the&nbsp;function&nbsp;when&nbsp;computing&nbsp;the&nbsp;asset.<br><br>Unlike&nbsp;an&nbsp;op,&nbsp;whose&nbsp;dependencies&nbsp;are&nbsp;determined&nbsp;by&nbsp;the&nbsp;graph&nbsp;it&nbsp;lives&nbsp;inside,&nbsp;an&nbsp;asset&nbsp;knows<br>about&nbsp;the&nbsp;upstream&nbsp;assets&nbsp;it&nbsp;depends&nbsp;on.&nbsp;The&nbsp;upstream&nbsp;assets&nbsp;are&nbsp;inferred&nbsp;from&nbsp;the&nbsp;arguments<br>to&nbsp;the&nbsp;decorated&nbsp;function.&nbsp;The&nbsp;name&nbsp;of&nbsp;the&nbsp;argument&nbsp;designates&nbsp;the&nbsp;name&nbsp;of&nbsp;the&nbsp;upstream&nbsp;asset.<br><br>An&nbsp;asset&nbsp;has&nbsp;an&nbsp;op&nbsp;inside&nbsp;it&nbsp;to&nbsp;represent&nbsp;the&nbsp;function&nbsp;that&nbsp;computes&nbsp;it.&nbsp;The&nbsp;name&nbsp;of&nbsp;the&nbsp;op<br>will&nbsp;be&nbsp;the&nbsp;segments&nbsp;of&nbsp;the&nbsp;asset&nbsp;key,&nbsp;separated&nbsp;by&nbsp;double-underscores.<br><br>Args:<br>&nbsp;&nbsp;&nbsp;&nbsp;name&nbsp;(Optional[str]):&nbsp;The&nbsp;name&nbsp;of&nbsp;the&nbsp;asset.&nbsp;&nbs ...
